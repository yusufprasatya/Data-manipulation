# %%
import pandas as pd
import numpy as np

# %%
myList = [['Apple','Red'],['Banana','Yellow'],['Orange','Orange']]

# %%
myDataFrame = pd.DataFrame(myList)
myDataFrame
# Out:
#         0       1
# 0   Apple     Red
# 1  Banana  Yellow
# 2  Orange  Orange

# %%
myDataFrame = pd.DataFrame(myList, columns=['Fruit','Color'])
myDataFrame
# Out:
#     Fruit   Color
# 0   Apple     Red
# 1  Banana  Yellow
# 2  Orange  Orange

# %%
# Using numpy array
myData = np.array([[0,1],[2,3],[4,6]])

myDataFrame = pd.DataFrame(myData, columns=['Even','Odd'])
myDataFrame
# Out:
#    Even  Odd
# 0     0    1
# 1     2    3
# 2     4    6

# %%
# Using dictionaries
myDictionaries = {'Fruite':['Banana','Cokelat','Strawberry'], 'Color':['Yellow','Cokelat','Pink']}
myDataFrame = pd.DataFrame(myDictionaries)
myDataFrame
# Out:
#        Fruite    Color
# 0      Banana   Yellow
# 1     Cokelat  Cokelat
# 2  Strawberry     Pink

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df[['Glucose','Age']]
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 3         89   21
# 4        137   33
# ..       ...  ...
# 763      101   63
# 764      122   27
# 765      121   30
# 766      126   47
# 767       93   23
#
# [768 rows x 2 columns]

# %%
condition = df['Age'] > 65
df[condition]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 123            5      132             80              0        0  26.8
# 221            2      158             90              0        0  31.6
# 363            4      146             78              0        0  38.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
# 489            8      194             80              0        0  26.1
# 495            6      166             74              0        0  26.6
# 537            0       57             60              0        0  21.7
# 552            6      114             88              0        0  27.8
# 666            4      145             82             18        0  32.5
# 674            8       91             82              0        0  35.6
# 684            5      136             82              0        0   0.0
# ...

# %%
df[(df['Age'] < 30) & (df['BMI'] < 20)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 33             6       92             92              0        0  19.9
# 49             7      105              0              0        0   0.0
# 50             1      103             80             11       82  19.4
# 60             2       84              0              0        0   0.0
# 68             1       95             66             13       38  19.6
# 81             2       74              0              0        0   0.0
# 90             1       80             55              0        0  19.1
# 145            0      102             75             23        0   0.0
# 239            0      104             76              0        0  18.4
# 371            0      118             64             23       89   0.0
# 418            1       83             68              0        0  18.2
# 426            0       94              0              0        0   0.0
# ...

# %%
df.drop(763, axis=0, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Add coloumn to dDataFrame
# df.head()
# df['My coloumn'] = ['A','B','C','D']

# %%
df.sort_values(by='BMI')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 684            5      136             82              0        0   0.0
# 145            0      102             75             23        0   0.0
# 371            0      118             64             23       89   0.0
# 60             2       84              0              0        0   0.0
# 426            0       94              0              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 120            0      162             76             56      100  53.2
# 125            1       88             30             42       99  55.0
# 673            3      123            100             35      240  57.3
# 445            0      180             78             63       14  59.4
# 177            0      129            110             46      130  67.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 684                     0.640   69        0
# ...

# %%
df.sort_values(by='BMI', ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 177            0      129            110             46      130  67.1
# 445            0      180             78             63       14  59.4
# 673            3      123            100             35      240  57.3
# 125            1       88             30             42       99  55.0
# 120            0      162             76             56      100  53.2
# ..           ...      ...            ...            ...      ...   ...
# 426            0       94              0              0        0   0.0
# 81             2       74              0              0        0   0.0
# 684            5      136             82              0        0   0.0
# 145            0      102             75             23        0   0.0
# 522            6      114              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 177                     0.319   26        1
# ...

# %%
# Save DataFrame to CSV
df.to_csv('MyFilecsv', index_label=False)

# %%
newDf = pd.read_csv('MyFilecsv')
newDf
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1 = df[5:10]
df1
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 7                      0.134   29        0
# 8                      0.158   53        1
# 9                      0.232   54        1
# 10                     0.191   30        0
# 11                     0.537   34        1

# %%
df2 = df[200:205]
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 202            0      108             68             20        0  27.3
# 203            2       99             70             16       44  20.4
# 204            6      103             72             32      190  37.7
# 205            5      111             72             28        0  23.9
# 206            8      196             76             29      280  37.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 202                     0.787   32        0
# 203                     0.235   27        0
# 204                     0.324   55        0
# 205                     0.407   27        0
# 206                     0.605   57        1

# %%
pd.concat([df1,df1], axis=1)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
#
#     DiabetesPedigreeFunction  Age  Outcome  Pregnancies  Glucose  \
# 7                      0.134   29        0           10      115
# 8                      0.158   53        1            2      197
# 9                      0.232   54        1            8      125
# 10                     0.191   30        0            4      110
# 11                     0.537   34        1           10      168
#
#     BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  \
# 7               0              0        0  35.3                     0.134
# ...

# %%
df
df.groupby(['Outcome']).count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                498      498            498            498      498  498
# 1                267      267            267            267      267  267
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             498  498
# 1                             267  267
